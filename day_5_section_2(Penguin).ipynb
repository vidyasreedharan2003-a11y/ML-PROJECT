# %% [markdown]
# <a href="https://colab.research.google.com/github/vidyasreedharan2003-a11y/ML-PROJECT/blob/main/day_5_section_2(Penguin).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Diampnds

# %%
import numpy as np
import pandas as ps
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('penguins')

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df.shape
# Out:
# (344, 7)

# %%
df.size
# Out:
# 2408

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df.sex.value_counts()
# Out:
# sex
# Male      168
# Female    165
# Name: count, dtype: int64

# %%
df.count()
# Out:
# species              344
# island               344
# bill_length_mm       342
# bill_depth_mm        342
# flipper_length_mm    342
# body_mass_g          342
# sex                  333
# dtype: int64

# %%
df.isnull().sum(axis=1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      5
# 4      0
#       ..
# 339    5
# 340    0
# 341    0
# 342    0
# 343    0
# Length: 344, dtype: int64

# %%
df.dropna(subset=['bill_length_mm','flipper_length_mm'],inplace=True)

# %%
df['sex']=df['sex'].fillna(df['sex'].mode()[0])

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [342 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
numerical_col=df.select_dtypes(include=np.number).columns

for col in numerical_col:
  plt.figure(figsize=(8,6))
  sns.histplot(df[col],kde=True)
  plt.title(f"Box plot of {col}")
  plt.show()

# %%
numerical_col=df.select_dtypes(include=np.number).columns

for col in numerical_col:
  plt.figure(figsize=(8,6))
  sns.boxplot(y=df[col])
  plt.title(f"Box plot of {col}")
  plt.show()

# %%
# df['sex']=df['sex'].map({'Male':1,'Female':0})

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['sex']=le.fit_transform(df['sex'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 342 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            342 non-null    object
#  1   island             342 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                342 non-null    int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 21.4+ KB

# %%
# df['sex'] = df['sex'].astype('int64')

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    1
# 1         3800.0    0
# 2         3250.0    0
# 4         3450.0    0
# 5         3650.0    1
# ..           ...  ...
# 338       4925.0    0
# 340       4850.0    0
# 341       5750.0    1
# 342       5200.0    0
# 343       5400.0    1
#
# [342 rows x 7 columns]

# %%
df['island'].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
import pandas as pd

#Oe hot

df=pd.get_dummies(data=df,columns=['island'],prefix="island",drop_first=True)

# %%
df
# Out:
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0    Adelie            39.1           18.7              181.0       3750.0
# 1    Adelie            39.5           17.4              186.0       3800.0
# 2    Adelie            40.3           18.0              195.0       3250.0
# 4    Adelie            36.7           19.3              193.0       3450.0
# 5    Adelie            39.3           20.6              190.0       3650.0
# ..      ...             ...            ...                ...          ...
# 338  Gentoo            47.2           13.7              214.0       4925.0
# 340  Gentoo            46.8           14.3              215.0       4850.0
# 341  Gentoo            50.4           15.7              222.0       5750.0
# 342  Gentoo            45.2           14.8              212.0       5200.0
# 343  Gentoo            49.9           16.1              213.0       5400.0
#
#      sex  island_Dream  island_Torgersen
# 0      1         False              True
# 1      0         False              True
# 2      0         False              True
# 4      0         False              True
# 5      1         False              True
# ..   ...           ...               ...
# 338    0         False             False
# 340    0         False             False
# 341    1         False             False
# 342    0         False             False
# 343    1         False             False
#
# [342 rows x 8 columns]

# %%
from scipy.stats import skew
cat_value=df.select_dtypes(include=["object"]).columns
num_value=df.select_dtypes(include=["int64","float64"]).columns

skew_value=df[num_value].skew()

# %%
skew_value
# Out:
# bill_length_mm       0.053118
# bill_depth_mm       -0.143465
# flipper_length_mm    0.345682
# body_mass_g          0.470329
# sex                 -0.070528
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
df['flipper_length_mm']=ss.fit_transform(df[['flipper_length_mm']])

# %%
df
# Out:
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0    Adelie            39.1           18.7          -1.418347       3750.0
# 1    Adelie            39.5           17.4          -1.062250       3800.0
# 2    Adelie            40.3           18.0          -0.421277       3250.0
# 4    Adelie            36.7           19.3          -0.563715       3450.0
# 5    Adelie            39.3           20.6          -0.777373       3650.0
# ..      ...             ...            ...                ...          ...
# 338  Gentoo            47.2           13.7           0.931890       4925.0
# 340  Gentoo            46.8           14.3           1.003109       4850.0
# 341  Gentoo            50.4           15.7           1.501644       5750.0
# 342  Gentoo            45.2           14.8           0.789451       5200.0
# 343  Gentoo            49.9           16.1           0.860670       5400.0
#
#      sex  island_Dream  island_Torgersen
# 0      1         False              True
# 1      0         False              True
# 2      0         False              True
# 4      0         False              True
# 5      1         False              True
# ..   ...           ...               ...
# 338    0         False             False
# 340    0         False             False
# 341    1         False             False
# 342    0         False             False
# 343    1         False             False
#
# [342 rows x 8 columns]

# %%
bol_cols=df.select_dtypes(include='bool').columns
df[bol_cols]=df[bol_cols].astype(int)

# %%
df
# Out:
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0    Adelie            39.1           18.7          -1.418347       3750.0
# 1    Adelie            39.5           17.4          -1.062250       3800.0
# 2    Adelie            40.3           18.0          -0.421277       3250.0
# 4    Adelie            36.7           19.3          -0.563715       3450.0
# 5    Adelie            39.3           20.6          -0.777373       3650.0
# ..      ...             ...            ...                ...          ...
# 338  Gentoo            47.2           13.7           0.931890       4925.0
# 340  Gentoo            46.8           14.3           1.003109       4850.0
# 341  Gentoo            50.4           15.7           1.501644       5750.0
# 342  Gentoo            45.2           14.8           0.789451       5200.0
# 343  Gentoo            49.9           16.1           0.860670       5400.0
#
#      sex  island_Dream  island_Torgersen
# 0      1             0                 1
# 1      0             0                 1
# 2      0             0                 1
# 4      0             0                 1
# 5      1             0                 1
# ..   ...           ...               ...
# 338    0             0                 0
# 340    0             0                 0
# 341    1             0                 0
# 342    0             0                 0
# 343    1             0                 0
#
# [342 rows x 8 columns]

# %%
y=df['species']
x=df.drop(['species'],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train.shape
# Out:
# (256, 7)

# %%
y_train.shape
# Out:
# (256,)

# %%
x_test.shape
# Out:
# (86, 7)

# %%
from sklearn.linear_model import LogisticRegression
lr_model=LogisticRegression()
lr_model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_predict=lr_model.predict(x_test)
y_predict
# Out:
# array(['Gentoo', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Gentoo',
#        'Chinstrap', 'Chinstrap', 'Gentoo', 'Adelie', 'Adelie', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Adelie', 'Chinstrap', 'Adelie', 'Adelie',
#        'Chinstrap', 'Adelie', 'Chinstrap', 'Adelie', 'Gentoo', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Chinstrap', 'Adelie', 'Gentoo',
#        'Chinstrap', 'Adelie', 'Adelie', 'Gentoo', 'Adelie', 'Adelie',
#        'Chinstrap', 'Gentoo', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Gentoo', 'Gentoo', 'Adelie', 'Chinstrap', 'Gentoo', 'Gentoo',
#        'Adelie', 'Adelie', 'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie',
#        'Adelie', 'Chinstrap', 'Adelie', 'Gentoo', 'Gentoo', 'Adelie',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Chinstrap', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Adelie', 'Gentoo', 'Chinstrap',
#        'Gentoo', 'Adelie', 'Adelie', 'Gentoo', 'Adelie', 'Gentoo',
#        'Adelie', 'Adelie'], dtype=object)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,precision_score

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[44,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0, 29]])

# %%
accuracy=accuracy_score(y_test,y_predict)

# %%
accuracy
# Out:
# 1.0

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model=DecisionTreeClassifier(criterion='gini',max_depth=5,min_samples_split=10,random_state=42,min_samples_leaf=10)
dt_model.fit(x_train,y_train)
y_pred=dt_model.predict(x_test)
print(accuracy_score(y_test,y_pred))
confusion_matrix(y_test,y_pred)
# Out:
# 0.9186046511627907
# array([[40,  4,  0],
#        [ 2, 11,  0],
#        [ 0,  1, 28]])

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model=RandomForestClassifier(n_estimators=20,
                                max_depth=10,
                                min_samples_split=3)
rf_model.fit(x_train,y_train)
y_pred=rf_model.predict(x_test)
print(accuracy_score(y_test,y_pred))
confusion_matrix(y_test,y_pred)
# Out:
# 0.9883720930232558
# array([[43,  1,  0],
#        [ 0, 13,  0],
#        [ 0,  0, 29]])
